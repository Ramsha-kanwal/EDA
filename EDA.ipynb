# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create sample dataset
data = {
    'Name': ['Ali', 'Sara', 'Ahmed', 'Ayesha', 'Usman'],
    'Study_Hours': [2, 5, 3, 6, 4],
    'Marks': [40, 75, 50, 85, 65]
}

df = pd.DataFrame(data)

# 1. View data
print(df.head())

# 2. Basic information
print(df.info())

# 3. Statistical summary
print(df.describe())

# 4. Check missing values
print(df.isnull().sum())

# 5. Visualization

# Histogram
df['Marks'].hist()
plt.title("Marks Distribution")
plt.show()

# Scatter plot
plt.scatter(df['Study_Hours'], df['Marks'])
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")
plt.show()

# Box plot
sns.boxplot(x=df['Marks'])
plt.title("Boxplot of Marks")
plt.show()

# Correlation
print(df.corr(numeric_only=True))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.show()
# Out:
#      Name  Study_Hours  Marks
# 0     Ali            2     40
# 1    Sara            5     75
# 2   Ahmed            3     50
# 3  Ayesha            6     85
# 4   Usman            4     65
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5 non-null      str
#  1   Study_Hours  5 non-null      int64
#  2   Marks        5 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 252.0 bytes
# None
#        Study_Hours      Marks
# count     5.000000   5.000000
# mean      4.000000  63.000000
# std       1.581139  18.234583
# min       2.000000  40.000000
# 25%       3.000000  50.000000
# 50%       4.000000  65.000000
# 75%       5.000000  75.000000
# max       6.000000  85.000000
# Name           0
# Study_Hours    0
# Marks          0
# dtype: int64
#              Study_Hours     Marks
# Study_Hours     1.000000  0.997176
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample dataset
data = {
    'Study_Hours': [2, 5, 3, 6, 4],
    'Marks': [40, 75, 50, 85, 65],
    'Sleep_Hours': [6, 7, 5, 8, 6]
}

df = pd.DataFrame(data)

# Correlation matrix
corr = df.corr()

# Plot single summary chart
plt.figure()
plt.imshow(corr)
plt.colorbar()

# Labels
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("EDA Summary (Correlation Heatmap)")
plt.show()
